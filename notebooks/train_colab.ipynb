# %% [markdown]
# # Casting Defect Classifier -- Colab Training
# Run this notebook on Google Colab with a GPU runtime (Runtime > Change runtime type > T4 GPU).

# %%
# Cell 1 -- Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Cell 2 -- Navigate to repo and pull latest changes
import os
os.chdir('/content/drive/MyDrive/Projects/defect_detection')
# !git pull
# !ls

# %%
# Cell 3 -- Install dependencies
# !pip install -r requirements-colab.txt -q

# %%
# Cell 4 -- Verify GPU is available
import torch
print(f'GPU available: {torch.cuda.is_available()}')
print(f'GPU name: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None"}')

# %%
import os
import yaml

# Generate config_colab.yaml from config.yaml
with open('configs/config.yaml', 'r') as f:
    config = yaml.safe_load(f)

config['data']['train_dir'] = '/content/data/train'
config['data']['test_dir'] = '/content/data/test'
config['data']['num_workers'] = 2
config['training']['epochs'] = 20
config['training']['learning_rate'] = 0.0001

with open('configs/config_colab.yaml', 'w') as f:
    yaml.dump(config, f)

# Copy dataset to local storage only if not already there
if not os.path.exists('/content/data/train'):
    print('Copying dataset to local storage...')
    # !cp -r /content/drive/MyDrive/Projects/defect_detection/data /content/data
    print('Dataset ready.')
else:
    print('Dataset already in local storage, skipping copy.')

# %%
# Cell 5 -- Run training
# !python -m src.train --config configs/config_colab.yaml
